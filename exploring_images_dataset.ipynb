# %%
# !wget https://storage.googleapis.com/ads-dataset/subfolder-0.zip
# !wget https://storage.googleapis.com/ads-dataset/subfolder-1.zip
# Out:
# --2024-05-31 02:32:12--  https://storage.googleapis.com/ads-dataset/subfolder-0.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.212.207, 173.194.213.207, 173.194.215.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.212.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 552295269 (527M) [application/zip]
# Saving to: ‘subfolder-0.zip’
#
# subfolder-0.zip     100%[===================>] 526.71M   103MB/s    in 5.1s
#
# 2024-05-31 02:32:17 (103 MB/s) - ‘subfolder-0.zip’ saved [552295269/552295269]
#
# --2024-05-31 02:32:17--  https://storage.googleapis.com/ads-dataset/subfolder-1.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.212.207, 173.194.213.207, 173.194.215.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.212.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 525102442 (501M) [application/zip]
# ...

# %%
# !unzip images/subfolder-0.zip
# !unzip images/subfolder-1.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: 1/110131.jpg
#   inflating: 1/110141.jpg
#   inflating: 1/110151.jpg
#   inflating: 1/110181.jpg
#   inflating: 1/110191.jpg
#   inflating: 1/110201.jpg
#   inflating: 1/110211.jpg
#   inflating: 1/110221.jpg
#   inflating: 1/110261.jpg
#   inflating: 1/110321.jpg
#   inflating: 1/110331.jpg
#   inflating: 1/110341.jpg
#   inflating: 1/110361.jpg
#   inflating: 1/110461.jpg
#   inflating: 1/110481.jpg
#   inflating: 1/110551.jpg
#   inflating: 1/110651.jpg
#   inflating: 1/110671.jpg
#   inflating: 1/110691.jpg
#   inflating: 1/11071.jpg
#   inflating: 1/110711.jpg
#   inflating: 1/110761.jpg
#   inflating: 1/110771.jpg
#   inflating: 1/110791.jpg
#   inflating: 1/110801.jpg
#   inflating: 1/11081.jpg
#   inflating: 1/110841.jpg
#   inflating: 1/110851.jpg
#   inflating: 1/110861.jpg
#   inflating: 1/110891.jpg
#   inflating: 1/110901.jpg
#   inflating: 1/110931.jpg
#   inflating: 1/110941.jpg
# ...

# %%
# data_exploration.ipynb
import os
import matplotlib.pyplot as plt
from PIL import Image

# List all images
image_folder = '1'
image_files = [os.path.join(image_folder, f) for f in os.listdir(image_folder) if f.endswith('.jpg')]

# Display some sample images
plt.figure(figsize=(10, 10))
for i, img_path in enumerate(image_files[:9]):
    img = Image.open(img_path)
    plt.subplot(3, 3, i+1)
    plt.imshow(img)
    plt.axis('off')
plt.show()

# Summarize dataset contents
print(f"Total images: {len(image_files)}")
# Out:
# Total images: 5433
